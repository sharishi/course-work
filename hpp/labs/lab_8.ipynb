# %%
# main.py
from hourly_employee import HourlyEmployee
from salary_employee import SalaryEmployee


hourly_employee = HourlyEmployee("Alice",'069445673', 'alice.sincler@gmail.com', 'Software developer', '02/11/1987', number_of_hours=160, hourly_pay=20)
salary_employee = SalaryEmployee("Bob",'067433123', 'bob.sincler@gmail.com', 'Analyst', '14/12/1997',salary=3000)

# Выводим зарплату сотрудников
print(f"{hourly_employee.name} - Hourly Employee Salary: ${hourly_employee.calculate_salary()}")
print(f"{salary_employee.name} - Salary Employee Salary: ${salary_employee.calculate_salary()}")
# Out:
# Alice - Hourly Employee Salary: $3200
# Bob - Salary Employee Salary: $3000
