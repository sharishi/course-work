# %% [markdown]
# # Лабораторная №3

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Определите список значений в Python. Выведите на экран первое и
# третье значение из списка. Замените какое-то значение на другое, в
# списке.

# %%
my_list = [1,2,3]
new_list = list()

# %%
new_list.append(5)
new_list.append(6)
new_list.append(7)

# %%
my_list[0], my_list[2]
# Out:
# (1, 3)

# %%
new_list[2] = 15
new_list[2]
# Out:
# 15

# %%
print(new_list)
for item in new_list:
    print(item, end=':')
# Out:
# [5, 6, 15]
# 5:6:15:

# %%
print(1, 2, 3, sep='!')
# Out:
# 1!2!3

# %% [markdown]
# Определите кортеж данных в Python. Выведите на экран тип данных
# определенного кортежа (что бы убедится, что так оно и есть), а потом
# выведите на экран первое и последнее значение из кортежа.

# %%
my_tuple = (1,3,5,9,8)

# %%
type(my_tuple)
# Out:
# tuple

# %%
my_tuple[0], my_tuple[-1]
# Out:
# (1, 8)

# %% [markdown]
# Определите множество элементов (set) в Python. Используйте и
# значения, которые повторяются в данном множестве. Выведите все
# элементы множества на экран.

# %%
my_set = {1,2,3,5,7,7,9,9,10,9,10,2,9,12}
new_set = set(my_list)
type(new_set)
# Out:
# set

# %%
print(my_set)
# Out:
# {1, 2, 3, 5}

# %% [markdown]
# Создайте словарь на основе текстовых ключей и словарь на основе
# числовых ключей. Выведите по 1-2 элементов из каждого словаря.

# %%
text_dict = {
    "a": "first letter",
    "b": "second letter",
    "c": "third letter"
}

print("Dictionary elements:")
print("a:", text_dict["a"])
print("c:", text_dict["c"])
# Out:
# Dictionary elements:
# a: first letter
# c: third letter

# %%
num_dict = {
    1: "one",
    2: "two",
    3: "three"
}

print("Dictionary elements:")
print("1:", num_dict[1])
print("2:", num_dict[2])
# Out:
# Dictionary elements:
# 1: one
# 2: two

# %% [markdown]
# Измените какой-то определенный ранее тип данных в другой.
# Объясните, как вы это сделали и для чего это может понадобится,
# приводя примеры.

# %% [markdown]
# # Список ↔ Множество

# %% [markdown]
# Список в множество и наоборот

# %%
new_set = set(my_list)
new_set
# Out:
# {1, 2, 3}

# %% [markdown]
# # Список ↔ Кортеж

# %% [markdown]
# Список в кортеж и наоборот

# %%
new_tuple = tuple(new_list)
new_tuple
# Out:
# (5, 6, 15)

# %% [markdown]
# # Кортеж ↔ Множество

# %% [markdown]
# Кортеж в множество и наоборот

# %%
second_set = set(new_tuple)
second_set
# Out:
# {5, 6, 15}

# %% [markdown]
# # Список ↔ Словарь

# %% [markdown]
# Список в словарь если это список пар (кортежей) ключ-значение и словарь в список если есть два списка, один из которых содержит ключи, а другой — значения

# %%
second_dict = dict(zip(my_list, new_list))
second_dict
# Out:
# {1: 5, 2: 6, 3: 15}

# %%
items_list = list(num_dict.items())
items_list
# Out:
# [(1, 'one'), (2, 'two'), (3, 'three')]

# %%
keys_list = list(text_dict.keys())
values_list = list(text_dict.values())
keys_list, values_list
# Out:
# (['a', 'b', 'c'], ['first letter', 'second letter', 'third letter'])

# %% [markdown]
# # Кортеж ↔ Словарь

# %% [markdown]
# кортеж в словарь если кортеж содержит пары ключ-значение, и словарь в кортеж

# %%
items_tuple = tuple(text_dict.items())
items_tuple
# Out:
# (('a', 'first letter'), ('b', 'second letter'), ('c', 'third letter'))

# %% [markdown]
# # Множество ↔ Словарь

# %% [markdown]
# Непосредственно преобразовать множество в словарь нельзя, так как для словаря нужны пары ключ-значение. Однако можно создать словарь с ключами из множества и задать каждому ключу какое-то значение

# %%
third_dict = dict.fromkeys(my_set, 0)
third_dict
# Out:
# {1: 0, 2: 0, 3: 0, 5: 0}

# %%
values_set = set(text_dict.values())
values_set
# Out:
# {'first letter', 'second letter', 'third letter'}

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Создайте список из 3-х числовых элементов и список, состоящий из 3-х
# текстовых элементов, представляющие названия 3-х товаров. Потом
# создайте информацию, используя метод format() и заданные выше 6
# значений, в тех 2-х списках и которая представит название товара и его
# цену. Выведите эту информацию на экран.

# %%
num_list = [12,34,56]
text_list = ['куркума', 'гранат','облепиха']

# %%
for i in range(len(num_list)):
    info = "Стоимость продукта '{0}' составляет {1:.2f} леев".format(text_list[i], num_list[i])
    print(info)
# Out:
# Стоимость продукта 'куркума' составляет 12.00 леев
# Стоимость продукта 'гранат' составляет 34.00 леев
# Стоимость продукта 'облепиха' составляет 56.00 леев

# %% [markdown]
# Попросите у пользователя чтобы он ввел свой возраст (какое-то целое
# числовое значение). Преобразуйте в число а потом в каком-то
# арифметическом выражении. Потом выведите на экран результат
# (например: через 5 лет вам будет X), включенный к какой-то текст.
# Используйте оператор конкатенации и арифметические операторы.

# %%
users_age = int(input('Введите свой возраст:'))
print(f'Год назад Вам было {users_age - 1}, а через десять лет Вам будет {users_age + 10}')
# Out:
# Год назад Вам было 3, а через десять лет Вам будет 14

# %%
age = int(input('Введите свой возраст:'))
age_in_5_years = age + 5
print('Через 5 лет вам будет ' + str(age_in_5_years) + ' лет.')
# Out:
# Через 5 лет вам будет 12 лет.

# %% [markdown]
# Предложите несколько строк кода в которым будете использовать
# оператор ”in” или ”not in”. Представьте результат.

# %%
if 3 not in [1,4,5]:
    print('I am not in the list')
# Out:
# I am not in the list
