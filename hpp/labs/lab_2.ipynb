# %% [markdown]
# # Лабораторная работа №2

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Выведите сообщение-приветствие на экран, используя функцию print(). Сохраните
# файл в созданную ранее папку. Интерпретируйте код и заметьте результат.

# %%
print('Привет')
# Out:
# Привет

# %% [markdown]
# Определите 4 переменные, используя правильные названия для них в Python.
# Присвойте каждой из них, последовательно: числовое целое значение,
# вещественное значение, короткое текстовое значение, текстовое значение,
# которое занимает 3-4 строки.

# %%
integer_value = 20
float_value = 4.3
short_string = 'Во всем мне хочется дойти'
text = """До самой сути.
В работе, в поисках пути,
В сердечной смуте."""
print(text)
# Out:
# До самой сути.
# В работе, в поисках пути,
# В сердечной смуте.

# %% [markdown]
# Выведите на экран тип данных для двух определенных ранее переменных.

# %%
print(type(integer_value))
print(type(text))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# Для одной из определенных текстовых переменных, выведите длину текстовой
# строки.

# %%
print(len(text))
# Out:
# 59

# %% [markdown]
# Преобразуйте текст, сохраненный в одну из текстовых переменных в буквах из
# верхнего регистра. Выведите результат на экран.

# %%
print(text.upper())
# Out:
# ДО САМОЙ СУТИ.
# В РАБОТЕ, В ПОИСКАХ ПУТИ,
# В СЕРДЕЧНОЙ СМУТЕ.

# %%
text_upper = text.upper()
print(text_upper)
# Out:
# ДО САМОЙ СУТИ.
# В РАБОТЕ, В ПОИСКАХ ПУТИ,
# В СЕРДЕЧНОЙ СМУТЕ.

# %% [markdown]
# «Отрежьте», а потом выведите подстроку из какой-то текстовой переменной.

# %%
print(text[2:25:2])
# Out:
#  ао уи
#  аое

# %%
print(text[2:-4:3])
# Out:
#  м т
# ро, иапиВееос

# %%
print(text[:3])
# Out:
# До

# %% [markdown]
# Код выводит 2 строки:
# 1. Первая строка является результатом среза с 4 по 12 символ
# 2. Вторая строка это эта же подстрока только без пробелов вокруг

# %%
txt = "More results from text..."
substr = txt[4:12]
print(substr)
print(substr.strip())
# Out:
#  results
# results

# %% [markdown]
# Метод split() без аргументов разделяет строку по пробелам и возвращает список слов (подстрок) из строки.

# %%
txt = "More results from text..."
print(txt.split())
# Out:
# ['More', 'results', 'from', 'text...']
